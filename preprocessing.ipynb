# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from os import listdir

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('./drive', force_remount=True)

path_prefix = './drive/My Drive/CS48002-NetworkScience'
# Out:
# Mounted at ./drive

# %%
filename = "Google-Playstore.csv"
df = pd.read_csv(join(path_prefix, filename))

# %%
play_store = df.nlargest(10000, 'Maximum Installs')

# %%
play_store.shape
# Out:
# (10000, 24)

# %%
play_store.dtypes
# Out:
# App Name              object
# App Id                object
# Category              object
# Rating               float64
# Rating Count         float64
# Installs              object
# Minimum Installs     float64
# Maximum Installs       int64
# Free                    bool
# Price                float64
# Currency              object
# Size                  object
# Minimum Android       object
# Developer Id          object
# Developer Website     object
# Developer Email       object
# Released              object
# Last Updated          object
# Content Rating        object
# Privacy Policy        object
# Ad Supported            bool
# In App Purchases        bool
# Editors Choice          bool
# Scraped Time          object
# dtype: object

# %%
play_store.head(20)
# Out:
#                                          App Name  \
# 2155096                      Google Play services
# 881403                                    YouTube
# 1773294                                    Google
# 1733042          Google Maps - Navigate & Explore
# 1060335                     Google Text-to-Speech
# 944254               Google Chrome: Fast & Secure
# 2099458                                     Gmail
# 2011395               Android Accessibility Suite
# 893676                               Google Drive
# 2222701                                  Facebook
# 385470                         WhatsApp Messenger
# 167781    Google TV (previously Play Movies & TV)
# 1830962                             Google Photos
# 2095852  Messenger – Text and Video Chat for Free
# 925338                                   Hangouts
# 1429623                    Android System WebView
# 1643722                         Google Play Games
# 1275432                      Samsung Push Service
# 2056046     Google Duo - High Quality Video Calls
# 1108596                                  Currents
#
#                                           App Id                 Category  \
# 2155096                   com.google.android.gms                    Tools
# 881403                com.google.android.youtube  Video Players & Editors
# 1773294  com.google.android.googlequicksearchbox                    Tools
# 1733042             com.google.android.apps.maps           Travel & Local
# 1060335                   com.google.android.tts                    Tools
# 944254                        com.android.chrome            Communication
# 2099458                    com.google.android.gm            Communication
# 2011395       com.google.android.marvin.talkback                    Tools
# 893676              com.google.android.apps.docs             Productivity
# 2222701                      com.facebook.katana                   Social
# 385470                              com.whatsapp            Communication
# 167781                 com.google.android.videos  Video Players & Editors
# 1830962           com.google.android.apps.photos              Photography
# 2095852                        com.facebook.orca            Communication
# 925338                   com.google.android.talk            Communication
# 1429623               com.google.android.webview                    Tools
# 1643722            com.google.android.play.games            Entertainment
# 1275432                         com.sec.spp.push            Communication
# 2056046          com.google.android.apps.tachyon            Communication
# 1108596             com.google.android.apps.plus                   Social
#
#          Rating  Rating Count         Installs  Minimum Installs  \
# 2155096     4.2    35128398.0  10,000,000,000+      1.000000e+10
# 881403      4.4   112440547.0   5,000,000,000+      5.000000e+09
# 1773294     4.2    19798962.0   5,000,000,000+      5.000000e+09
# 1733042     3.8    13576045.0   5,000,000,000+      5.000000e+09
# 1060335     4.1      254700.0   5,000,000,000+      5.000000e+09
# 944254      4.1    31481796.0   5,000,000,000+      5.000000e+09
# 2099458     4.2     9488421.0   5,000,000,000+      5.000000e+09
# 2011395     4.2     2666450.0   5,000,000,000+      5.000000e+09
# 893676      4.3      639307.0   5,000,000,000+      5.000000e+09
# 2222701     2.3   117850066.0   5,000,000,000+      5.000000e+09
# 385470      4.0   138557570.0   5,000,000,000+      5.000000e+09
# 167781      4.0     1825673.0   5,000,000,000+      5.000000e+09
# 1830962     4.5    35369236.0   5,000,000,000+      5.000000e+09
# 2095852     4.0    78563229.0   5,000,000,000+      5.000000e+09
# 925338      4.0     5072462.0   5,000,000,000+      5.000000e+09
# 1429623     4.0     6045686.0   1,000,000,000+      1.000000e+09
# 1643722     4.3    12016421.0   1,000,000,000+      1.000000e+09
# 1275432     4.2     1160802.0   1,000,000,000+      1.000000e+09
# 2056046     4.5     7709623.0   1,000,000,000+      1.000000e+09
# 1108596     4.0     6359366.0   1,000,000,000+      1.000000e+09
#
#          Maximum Installs  Free  Price  ...  \
# 2155096       12057627016  True    0.0  ...
# 881403         9766230924  True    0.0  ...
# 1773294        9154248491  True    0.0  ...
# 1733042        9141671889  True    0.0  ...
# 1060335        9034404884  True    0.0  ...
# 944254         8925640788  True    0.0  ...
# 2099458        8756574289  True    0.0  ...
# 2011395        7408134567  True    0.0  ...
# 893676         7028265259  True    0.0  ...
# 2222701        6782619635  True    0.0  ...
# 385470         6265637751  True    0.0  ...
# 167781         6156518915  True    0.0  ...
# 1830962        5754179589  True    0.0  ...
# 2095852        5054312355  True    0.0  ...
# 925338         5019518222  True    0.0  ...
# 1429623        4764329349  True    0.0  ...
# 1643722        4605543029  True    0.0  ...
# 1275432        4186667750  True    0.0  ...
# 2056046        4022259636  True    0.0  ...
# 1108596        3929716163  True    0.0  ...
#
#                                          Developer Website  \
# 2155096  https://developers.google.com/android/google-p...
# 881403   https://support.google.com/youtube/topic/24225...
# 1773294               https://www.google.com/search/about/
# 1733042                      http://maps.google.com/about/
# 1060335                             http://www.google.com/
# 944254                http://www.google.com/chrome/android
# 2099458  http://support.google.com/mail/bin/topic.py?hl...
# 2011395  https://developer.android.com/guide/topics/ui/...
# 893676   https://support.google.com/drive/?p=android_dr...
# 2222701                  https://www.facebook.com/facebook
# 385470                            http://www.whatsapp.com/
# 167781                http://support.google.com/googleplay
# 1830962                  https://support.google.com/photos
# 2095852  https://www.facebook.com/games/fbmessenger_and...
# 925338   https://support.google.com/hangouts/?p=android...
# 1429623                             http://www.android.com
# 1643722    http://play.google.com/store/apps/category/GAME
# 1275432                                                NaN
# 2056046                                                NaN
# 1108596  https://support.google.com/plus/?hl=en#topic=6...
#
#                        Developer Email      Released  Last Updated  \
# 2155096           apps-help@google.com  May 24, 2012  Jun 10, 2021
# 881403    ytandroid-support@google.com  Oct 20, 2010  Jun 16, 2021
# 1773294           apps-help@google.com  Aug 12, 2010  Jun 11, 2021
# 1733042           apps-help@google.com           NaN  Jun 15, 2021
# 1060335        tts-feedback@google.com  Oct 10, 2013  Mar 29, 2021
# 944254            apps-help@google.com   Feb 7, 2012  Jun 14, 2021
# 2099458           apps-help@google.com  Sep 21, 2010  Jun 16, 2021
# 2011395           apps-help@google.com           NaN  May 19, 2021
# 893676            apps-help@google.com  Apr 27, 2011  Jun 09, 2021
# 2222701        facebook.android@fb.com           NaN  Jun 16, 2021
# 385470    android@support.whatsapp.com  Oct 18, 2010  Jun 09, 2021
# 167781            apps-help@google.com   Jun 3, 2011  Jun 14, 2021
# 1830962           apps-help@google.com  May 28, 2015  Jun 14, 2021
# 2095852         android-support@fb.com  Jan 30, 2014  Jun 14, 2021
# 925338            apps-help@google.com  May 15, 2013  May 14, 2021
# 1429623           apps-help@google.com  Mar 10, 2015  Jun 14, 2021
# 1643722  googleplay-support@google.com  Jul 24, 2013  Apr 26, 2021
# 1275432        noreply.sec@samsung.com  Mar 29, 2013  May 13, 2021
# 2056046           apps-help@google.com  Aug 16, 2016  Jun 15, 2021
# 1108596           apps-help@google.com  Jun 28, 2011  Jun 07, 2021
#
#         Content Rating                                     Privacy Policy  \
# 2155096       Everyone             http://www.google.com/policies/privacy
# 881403            Teen             http://www.google.com/policies/privacy
# 1773294       Everyone             http://www.google.com/policies/privacy
# 1733042       Everyone             http://www.google.com/policies/privacy
# 1060335       Everyone             http://www.google.com/policies/privacy
# 944254        Everyone  http://www.google.com/chrome/intl/en/privacy.html
# 2099458       Everyone             http://www.google.com/policies/privacy
# 2011395       Everyone             http://www.google.com/policies/privacy
# 893676        Everyone             http://www.google.com/policies/privacy
# 2222701           Teen            https://www.facebook.com/about/privacy/
# 385470        Everyone             http://www.whatsapp.com/legal/#Privacy
# 167781            Teen             http://www.google.com/policies/privacy
# 1830962       Everyone             http://www.google.com/policies/privacy
# 2095852       Everyone                  https://m.facebook.com/policy.php
# 925338        Everyone             http://www.google.com/policies/privacy
# 1429623       Everyone                                                NaN
# 1643722           Teen             http://www.google.com/policies/privacy
# 1275432       Everyone          https://account.samsung.com/membership/pp
# 2056046       Everyone             http://www.google.com/policies/privacy
# 1108596           Teen             http://www.google.com/policies/privacy
#
#         Ad Supported In App Purchases Editors Choice         Scraped Time
# 2155096        False            False          False  2021-06-16 10:41:26
# 881403          True            False          False  2021-06-16 10:28:37
# 1773294         True            False          False  2021-06-16 05:12:00
# 1733042         True            False           True  2021-06-16 04:38:02
# 1060335        False            False          False  2021-06-16 13:16:56
# 944254         False            False          False  2021-06-16 11:26:31
# 2099458         True            False          False  2021-06-16 09:53:00
# 2011395        False            False          False  2021-06-16 08:36:32
# 893676         False             True          False  2021-06-16 10:39:49
# 2222701         True             True          False  2021-06-16 11:40:20
# 385470         False            False           True  2021-06-16 02:51:24
# 167781         False            False          False  2021-06-15 23:07:22
# 1830962        False            False          False  2021-06-16 06:00:01
# 2095852        False             True           True  2021-06-16 09:49:47
# 925338         False            False          False  2021-06-16 11:09:02
# 1429623        False            False          False  2021-06-16 00:17:24
# 1643722        False            False          False  2021-06-16 03:24:06
# 1275432        False            False          False  2021-06-15 21:49:09
# 2056046        False            False          False  2021-06-16 09:15:11
# 1108596        False            False          False  2021-06-16 14:03:43
#
# [20 rows x 24 columns]

# %%
# Upload Permissions Dataset
filename = "permissions_dataset.csv"
permissions = pd.read_csv(join(path_prefix, filename))

# %%
permissions.shape
# Out:
# (2292693, 3)

# %%
permissions.rename(columns = {'appId':'App Id', 'allPermissions':'All Permissions'}, inplace = True)

# %%
permissions.drop(columns=['appName'], inplace=True)

# %%
permissions.sample(5)
# Out:
#                                   App Id  \
# 1556892                 com.pthree.admin
# 1172922          com.galacticthumb.ilift
# 161717               com.balambasik.dice
# 1257732  jp.co.a_tm.android.plus_message
# 326432    com.frederique.constant.hybrid
#
#                                            All Permissions
# 1556892  [{'permission': 'read the contents of your USB...
# 1172922  [{'permission': 'view Wi-Fi connections', 'typ...
# 161717   [{'permission': 'read phone status and identit...
# 1257732  [{'permission': 'read the contents of your USB...
# 326432   [{'permission': 'approximate location (network...

# %%
# Merge two datasets
data_df = pd.merge(permissions, play_store, on='App Id')

# %%
data_df.shape
# Out:
# (9990, 25)

# %%
data_df.head()
# Out:
#                                               App Id  \
# 0                  com.google.android.apps.messaging
# 1                    com.alp.traingamesfreesimulator
# 2                               com.rapido.passenger
# 3                                 de.aktiwir.aktibmi
# 4  com.gamevil.kritikamobile.android.google.globa...
#
#                                      All Permissions  \
# 0  [{'permission': 'modify or delete the contents...
# 1  [{'permission': 'view network connections', 't...
# 2  [{'permission': 'retrieve running apps', 'type...
# 3  [{'permission': 'find accounts on the device',...
# 4  [{'permission': 'retrieve running apps', 'type...
#
#                                             App Name           Category  \
# 0                                           Messages      Communication
# 1  Train Games Simulator : Indian Train Driving G...            Weather
# 2                                 Rapido - Bike Taxi  Maps & Navigation
# 3                Weight Loss Tracker & BMI - aktiBMI   Health & Fitness
# 4                         Kritika: The White Knights       Role Playing
#
#    Rating  Rating Count        Installs  Minimum Installs  Maximum Installs  \
# 0     4.4     5305758.0  1,000,000,000+      1.000000e+09        1931517750
# 1     4.1       21189.0      5,000,000+      5.000000e+06           9632078
# 2     4.1      701278.0     10,000,000+      1.000000e+07          23238658
# 3     4.5        4798.0      5,000,000+      5.000000e+06           9767859
# 4     4.3      880658.0     10,000,000+      1.000000e+07          25135365
#
#    Free  ...                      Developer Website  \
# 0  True  ...  http://www.google.com/mobile/android/
# 1  True  ...          https://www.bajakestudios.com
# 2  True  ...                https://www.rapido.bike
# 3  True  ...                 http://www.aktibmi.com
# 4  True  ...                http://www.withhive.com
#
#                Developer Email      Released  Last Updated Content Rating  \
# 0         apps-help@google.com  Nov 12, 2014  Jun 10, 2021       Everyone
# 1  info.2bitventures@gmail.com  Feb 16, 2017  May 16, 2021       Everyone
# 2         shoutout@rapido.bike  Sep 30, 2015  Jun 12, 2021       Everyone
# 3            aktiwir@gmail.com  May 30, 2015  Jun 09, 2021       Everyone
# 4             help@gamevil.com  May 29, 2014  Jun 02, 2021           Teen
#
#                                       Privacy Policy Ad Supported  \
# 0             http://www.google.com/policies/privacy        False
# 1           http://bajakestudios.com/privacy-policy/         True
# 2                   https://rapido.bike/privacy.html        False
# 3  http://www.aktibmi.com/cms/privacy-policy-akti...         True
# 4  http://terms.withhive.com/terms/bridge/gamevil...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-16 06:11:32
# 1             True          False  2021-06-16 03:41:11
# 2            False          False  2021-06-16 06:16:28
# 3             True          False  2021-06-16 06:03:47
# 4             True           True  2021-06-16 03:33:33
#
# [5 rows x 25 columns]
